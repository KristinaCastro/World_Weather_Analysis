# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import gmaps

# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 740

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_descp = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        #city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_descp})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | mataura
# Processing Record 2 of Set 1 | torbay
# Processing Record 3 of Set 1 | codrington
# Processing Record 4 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 5 of Set 1 | kapaa
# Processing Record 6 of Set 1 | dikson
# Processing Record 7 of Set 1 | tasiilaq
# Processing Record 8 of Set 1 | miranorte
# City not found. Skipping...
# Processing Record 9 of Set 1 | tubruq
# City not found. Skipping...
# Processing Record 10 of Set 1 | sola
# Processing Record 11 of Set 1 | provideniya
# Processing Record 12 of Set 1 | bethel
# Processing Record 13 of Set 1 | kodiak
# Processing Record 14 of Set 1 | berlevag
# Processing Record 15 of Set 1 | lagoa
# Processing Record 16 of Set 1 | norman wells
# Processing Record 17 of Set 1 | hilo
# Processing Record 18 of Set 1 | ushuaia
# Processing Record 19 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 20 of Set 1 | bredasdorp
# Processing Record 21 of Set 1 | busselton
# Processing Record 22 of Set 1 | kaitangata
# Processing Record 23 of Set 1 | fortuna
# Processing Record 24 of Set 1 | kruisfontein
# Processing Record 25 of Set 1 | jamestown
# Processing Record 26 of Set 1 | vaini
# Processing Record 27 of Set 1 | butaritari
# Processing Record 28 of Set 1 | mutoko
# Processing Record 29 of Set 1 | argir
# Processing Record 30 of Set 1 | port hedland
# Processing Record 31 of Set 1 | abashiri
# Processing Record 32 of Set 1 | albany
# Processing Record 33 of Set 1 | darnah
# Processing Record 34 of Set 1 | punta arenas
# Processing Record 35 of Set 1 | hokitika
# Processing Record 36 of Set 1 | hermanus
# Processing Record 37 of Set 1 | lebu
# Processing Record 38 of Set 1 | ponta do sol
# Processing Record 39 of Set 1 | bluff
# Processing Record 40 of Set 1 | saldanha
# Processing Record 41 of Set 1 | new norfolk
# Processing Record 42 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 43 of Set 1 | rawannawi
# City not found. Skipping...
# Processing Record 44 of Set 1 | cabo san lucas
# Processing Record 45 of Set 1 | kadykchan
# City not found. Skipping...
# Processing Record 46 of Set 1 | mount gambier
# Processing Record 47 of Set 1 | tocopilla
# Processing Record 48 of Set 1 | rikitea
# Processing Record 49 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 50 of Set 1 | halifax
# Processing Record 1 of Set 2 | thompson
# Processing Record 2 of Set 2 | severo-kurilsk
# Processing Record 3 of Set 2 | jinchengjiang
# City not found. Skipping...
# Processing Record 4 of Set 2 | bethanien
# Processing Record 5 of Set 2 | ust-kuyga
# Processing Record 6 of Set 2 | georgetown
# Processing Record 7 of Set 2 | vao
# Processing Record 8 of Set 2 | ostrovnoy
# Processing Record 9 of Set 2 | atuona
# Processing Record 10 of Set 2 | akdepe
# Processing Record 11 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 12 of Set 2 | adrar
# Processing Record 13 of Set 2 | hambantota
# Processing Record 14 of Set 2 | rio grande
# Processing Record 15 of Set 2 | karkaralinsk
# City not found. Skipping...
# Processing Record 16 of Set 2 | clyde river
# Processing Record 17 of Set 2 | margate
# Processing Record 18 of Set 2 | luderitz
# Processing Record 19 of Set 2 | flinders
# Processing Record 20 of Set 2 | ust-kulom
# Processing Record 21 of Set 2 | quatre cocos
# Processing Record 22 of Set 2 | nouadhibou
# Processing Record 23 of Set 2 | nome
# Processing Record 24 of Set 2 | maceio
# Processing Record 25 of Set 2 | puerto ayora
# Processing Record 26 of Set 2 | wote
# Processing Record 27 of Set 2 | hwange
# Processing Record 28 of Set 2 | saskylakh
# Processing Record 29 of Set 2 | port elizabeth
# Processing Record 30 of Set 2 | cape town
# Processing Record 31 of Set 2 | quang ngai
# Processing Record 32 of Set 2 | narodychi
# Processing Record 33 of Set 2 | mbandaka
# Processing Record 34 of Set 2 | saint-philippe
# Processing Record 35 of Set 2 | tumannyy
# City not found. Skipping...
# Processing Record 36 of Set 2 | rolim de moura
# City not found. Skipping...
# Processing Record 37 of Set 2 | tautira
# Processing Record 38 of Set 2 | male
# Processing Record 39 of Set 2 | marcona
# City not found. Skipping...
# Processing Record 40 of Set 2 | shimoda
# Processing Record 41 of Set 2 | alta floresta
# Processing Record 42 of Set 2 | port alfred
# Processing Record 43 of Set 2 | hobart
# Processing Record 44 of Set 2 | tuktoyaktuk
# Processing Record 45 of Set 2 | namatanai
# Processing Record 46 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 47 of Set 2 | san patricio
# Processing Record 48 of Set 2 | lorengau
# Processing Record 49 of Set 2 | les cayes
# Processing Record 50 of Set 2 | marquette
# Processing Record 1 of Set 3 | khatanga
# Processing Record 2 of Set 3 | castro
# Processing Record 3 of Set 3 | sistranda
# Processing Record 4 of Set 3 | broome
# Processing Record 5 of Set 3 | deputatskiy
# Processing Record 6 of Set 3 | mabaruma
# Processing Record 7 of Set 3 | salalah
# Processing Record 8 of Set 3 | namtsy
# Processing Record 9 of Set 3 | ankpa
# Processing Record 10 of Set 3 | sorland
# Processing Record 11 of Set 3 | masunga
# Processing Record 12 of Set 3 | umm kaddadah
# Processing Record 13 of Set 3 | araguatins
# City not found. Skipping...
# Processing Record 14 of Set 3 | vila velha
# Processing Record 15 of Set 3 | manado
# Processing Record 16 of Set 3 | ribeira grande
# Processing Record 17 of Set 3 | klaksvik
# Processing Record 18 of Set 3 | yuxia
# Processing Record 19 of Set 3 | canico
# Processing Record 20 of Set 3 | bellary
# Processing Record 21 of Set 3 | barrow
# Processing Record 22 of Set 3 | batagay-alyta
# Processing Record 23 of Set 3 | diamantino
# Processing Record 24 of Set 3 | longyearbyen
# Processing Record 25 of Set 3 | kerteh
# City not found. Skipping...
# Processing Record 26 of Set 3 | louisbourg
# City not found. Skipping...
# Processing Record 27 of Set 3 | souillac
# Processing Record 28 of Set 3 | avarua
# Processing Record 29 of Set 3 | kahului
# Processing Record 30 of Set 3 | komsomolskiy
# Processing Record 31 of Set 3 | yellowknife
# Processing Record 32 of Set 3 | ponta delgada
# Processing Record 33 of Set 3 | bengkulu
# Processing Record 34 of Set 3 | hannibal
# Processing Record 35 of Set 3 | bogorodskoye
# Processing Record 36 of Set 3 | avera
# Processing Record 37 of Set 3 | okhotsk
# Processing Record 38 of Set 3 | erenhot
# Processing Record 39 of Set 3 | jiujiang
# Processing Record 40 of Set 3 | tiffin
# Processing Record 41 of Set 3 | waingapu
# Processing Record 42 of Set 3 | coquimbo
# Processing Record 43 of Set 3 | airai
# Processing Record 44 of Set 3 | susangerd
# Processing Record 45 of Set 3 | atar
# Processing Record 46 of Set 3 | ancud
# Processing Record 47 of Set 3 | sataua
# City not found. Skipping...
# Processing Record 48 of Set 3 | sao miguel do araguaia
# Processing Record 49 of Set 3 | nortelandia
# Processing Record 50 of Set 3 | savannah bight
# Processing Record 1 of Set 4 | cidreira
# Processing Record 2 of Set 4 | honiara
# Processing Record 3 of Set 4 | kosonsoy
# Processing Record 4 of Set 4 | nagato
# Processing Record 5 of Set 4 | mar del plata
# Processing Record 6 of Set 4 | chifeng
# Processing Record 7 of Set 4 | arraial do cabo
# Processing Record 8 of Set 4 | maniitsoq
# Processing Record 9 of Set 4 | pringsewu
# Processing Record 10 of Set 4 | vardo
# Processing Record 11 of Set 4 | sao filipe
# Processing Record 12 of Set 4 | saint george
# Processing Record 13 of Set 4 | beringovskiy
# Processing Record 14 of Set 4 | mogadishu
# Processing Record 15 of Set 4 | brae
# Processing Record 16 of Set 4 | singleton
# Processing Record 17 of Set 4 | saint-augustin
# Processing Record 18 of Set 4 | watertown
# Processing Record 19 of Set 4 | bilma
# Processing Record 20 of Set 4 | seoul
# Processing Record 21 of Set 4 | lakes entrance
# Processing Record 22 of Set 4 | tuatapere
# Processing Record 23 of Set 4 | nikolskoye
# Processing Record 24 of Set 4 | mount isa
# Processing Record 25 of Set 4 | geraldton
# Processing Record 26 of Set 4 | nuoro
# Processing Record 27 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 28 of Set 4 | bambous virieux
# Processing Record 29 of Set 4 | sao felix do xingu
# Processing Record 30 of Set 4 | qaqortoq
# Processing Record 31 of Set 4 | talcahuano
# Processing Record 32 of Set 4 | garden city
# Processing Record 33 of Set 4 | port hardy
# Processing Record 34 of Set 4 | tabiauea
# City not found. Skipping...
# Processing Record 35 of Set 4 | the pas
# Processing Record 36 of Set 4 | muswellbrook
# Processing Record 37 of Set 4 | itacare
# Processing Record 38 of Set 4 | dabat
# Processing Record 39 of Set 4 | leningradskiy
# Processing Record 40 of Set 4 | alofi
# Processing Record 41 of Set 4 | tyup
# Processing Record 42 of Set 4 | mahebourg
# Processing Record 43 of Set 4 | vikhorevka
# Processing Record 44 of Set 4 | tiksi
# Processing Record 45 of Set 4 | simao
# Processing Record 46 of Set 4 | melfi
# Processing Record 47 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 48 of Set 4 | tanete
# Processing Record 49 of Set 4 | dharchula
# Processing Record 50 of Set 4 | gazli
# Processing Record 1 of Set 5 | sitka
# Processing Record 2 of Set 5 | victoria
# Processing Record 3 of Set 5 | hasaki
# Processing Record 4 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 5 of Set 5 | glubokoe
# City not found. Skipping...
# Processing Record 6 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 7 of Set 5 | bolungarvik
# City not found. Skipping...
# Processing Record 8 of Set 5 | coihaique
# Processing Record 9 of Set 5 | raudeberg
# Processing Record 10 of Set 5 | manggar
# Processing Record 11 of Set 5 | dharampur
# Processing Record 12 of Set 5 | orsha
# Processing Record 13 of Set 5 | ahipara
# Processing Record 14 of Set 5 | saint anthony
# Processing Record 15 of Set 5 | kavaratti
# Processing Record 16 of Set 5 | palaikastron
# Processing Record 17 of Set 5 | bonfim
# Processing Record 18 of Set 5 | nantucket
# Processing Record 19 of Set 5 | luau
# Processing Record 20 of Set 5 | bialystok
# Processing Record 21 of Set 5 | qandala
# Processing Record 22 of Set 5 | novyy urengoy
# Processing Record 23 of Set 5 | qaanaaq
# Processing Record 24 of Set 5 | touho
# Processing Record 25 of Set 5 | olafsvik
# Processing Record 26 of Set 5 | verkhoyansk
# Processing Record 27 of Set 5 | comodoro rivadavia
# Processing Record 28 of Set 5 | lompoc
# Processing Record 29 of Set 5 | lazaro cardenas
# Processing Record 30 of Set 5 | roald
# Processing Record 31 of Set 5 | kodinsk
# Processing Record 32 of Set 5 | cherskiy
# Processing Record 33 of Set 5 | san quintin
# Processing Record 34 of Set 5 | bogalusa
# Processing Record 35 of Set 5 | kununurra
# Processing Record 36 of Set 5 | sokoni
# Processing Record 37 of Set 5 | monrovia
# Processing Record 38 of Set 5 | japura
# Processing Record 39 of Set 5 | bayji
# Processing Record 40 of Set 5 | anadyr
# Processing Record 41 of Set 5 | kashi
# Processing Record 42 of Set 5 | hamilton
# Processing Record 43 of Set 5 | alghero
# Processing Record 44 of Set 5 | usinsk
# Processing Record 45 of Set 5 | dzaoudzi
# Processing Record 46 of Set 5 | boddam
# Processing Record 47 of Set 5 | narsaq
# Processing Record 48 of Set 5 | znamenskoye
# Processing Record 49 of Set 5 | nanortalik
# Processing Record 50 of Set 5 | lukhovka
# Processing Record 1 of Set 6 | ambon
# Processing Record 2 of Set 6 | barstow
# Processing Record 3 of Set 6 | ballina
# Processing Record 4 of Set 6 | buin
# Processing Record 5 of Set 6 | panaba
# Processing Record 6 of Set 6 | madimba
# Processing Record 7 of Set 6 | sarangani
# Processing Record 8 of Set 6 | churapcha
# Processing Record 9 of Set 6 | bindura
# Processing Record 10 of Set 6 | tanjong karang
# City not found. Skipping...
# Processing Record 11 of Set 6 | hofn
# Processing Record 12 of Set 6 | vaitape
# Processing Record 13 of Set 6 | burns lake
# Processing Record 14 of Set 6 | bargal
# City not found. Skipping...
# Processing Record 15 of Set 6 | slave lake
# Processing Record 16 of Set 6 | ilulissat
# Processing Record 17 of Set 6 | aklavik
# Processing Record 18 of Set 6 | fort oglethorpe
# Processing Record 19 of Set 6 | eureka
# Processing Record 20 of Set 6 | cherdyn
# Processing Record 21 of Set 6 | utiroa
# City not found. Skipping...
# Processing Record 22 of Set 6 | port hueneme
# Processing Record 23 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 24 of Set 6 | itaituba
# Processing Record 25 of Set 6 | warqla
# City not found. Skipping...
# Processing Record 26 of Set 6 | vestmanna
# Processing Record 27 of Set 6 | iqaluit
# Processing Record 28 of Set 6 | montepuez
# Processing Record 29 of Set 6 | kuytun
# Processing Record 30 of Set 6 | arman
# Processing Record 31 of Set 6 | east london
# Processing Record 32 of Set 6 | merano
# Processing Record 33 of Set 6 | vila
# Processing Record 34 of Set 6 | pangnirtung
# Processing Record 35 of Set 6 | vyartsilya
# Processing Record 36 of Set 6 | buraydah
# Processing Record 37 of Set 6 | burlatskoye
# Processing Record 38 of Set 6 | neuquen
# Processing Record 39 of Set 6 | hithadhoo
# Processing Record 40 of Set 6 | hernani
# Processing Record 41 of Set 6 | tunceli
# Processing Record 42 of Set 6 | pasaco
# Processing Record 43 of Set 6 | chuy
# Processing Record 44 of Set 6 | yola
# Processing Record 45 of Set 6 | hualmay
# Processing Record 46 of Set 6 | mumford
# Processing Record 47 of Set 6 | severnoye
# Processing Record 48 of Set 6 | le port
# Processing Record 49 of Set 6 | kurtamysh
# Processing Record 50 of Set 6 | mayor pablo lagerenza
# Processing Record 1 of Set 7 | la libertad
# Processing Record 2 of Set 7 | kirensk
# Processing Record 3 of Set 7 | ambulu
# Processing Record 4 of Set 7 | touros
# Processing Record 5 of Set 7 | siocon
# Processing Record 6 of Set 7 | kenitra
# Processing Record 7 of Set 7 | tomatlan
# Processing Record 8 of Set 7 | zhaotong
# Processing Record 9 of Set 7 | vaitupu
# City not found. Skipping...
# Processing Record 10 of Set 7 | guajara-mirim
# City not found. Skipping...
# Processing Record 11 of Set 7 | laurel
# Processing Record 12 of Set 7 | san carlos
# Processing Record 13 of Set 7 | pevek
# Processing Record 14 of Set 7 | kilingi-nomme
# Processing Record 15 of Set 7 | bilibino
# Processing Record 16 of Set 7 | biak
# Processing Record 17 of Set 7 | nioki
# Processing Record 18 of Set 7 | lafayette
# Processing Record 19 of Set 7 | kainantu
# Processing Record 20 of Set 7 | lavumisa
# Processing Record 21 of Set 7 | jati
# Processing Record 22 of Set 7 | ruwi
# Processing Record 23 of Set 7 | saint-pierre
# Processing Record 24 of Set 7 | chapais
# Processing Record 25 of Set 7 | chokurdakh
# Processing Record 26 of Set 7 | upernavik
# Processing Record 27 of Set 7 | awbari
# Processing Record 28 of Set 7 | omsukchan
# Processing Record 29 of Set 7 | foz do iguacu
# Processing Record 30 of Set 7 | puerto carreno
# Processing Record 31 of Set 7 | presidencia roque saenz pena
# Processing Record 32 of Set 7 | chernyshevskiy
# Processing Record 33 of Set 7 | necochea
# Processing Record 34 of Set 7 | constitucion
# Processing Record 35 of Set 7 | shatrovo
# Processing Record 36 of Set 7 | hobyo
# Processing Record 37 of Set 7 | providencia
# Processing Record 38 of Set 7 | pimentel
# Processing Record 39 of Set 7 | biga
# Processing Record 40 of Set 7 | matagami
# Processing Record 41 of Set 7 | ahar
# Processing Record 42 of Set 7 | hervey bay
# Processing Record 43 of Set 7 | leshukonskoye
# Processing Record 44 of Set 7 | ngorongoro
# Processing Record 45 of Set 7 | guerrero negro
# Processing Record 46 of Set 7 | dejen
# Processing Record 47 of Set 7 | camopi
# Processing Record 48 of Set 7 | palana
# Processing Record 49 of Set 7 | naranjito
# Processing Record 50 of Set 7 | umzimvubu
# City not found. Skipping...
# Processing Record 1 of Set 8 | bolonchen
# City not found. Skipping...
# Processing Record 2 of Set 8 | huilong
# Processing Record 3 of Set 8 | whitehorse
# Processing Record 4 of Set 8 | chara
# Processing Record 5 of Set 8 | hovd
# Processing Record 6 of Set 8 | lata
# Processing Record 7 of Set 8 | hohhot
# Processing Record 8 of Set 8 | thinadhoo
# Processing Record 9 of Set 8 | poenari
# Processing Record 10 of Set 8 | surt
# Processing Record 11 of Set 8 | novyy urgal
# Processing Record 12 of Set 8 | olden
# Processing Record 13 of Set 8 | williams lake
# Processing Record 14 of Set 8 | kovur
# Processing Record 15 of Set 8 | atikokan
# Processing Record 16 of Set 8 | yulara
# Processing Record 17 of Set 8 | oranjemund
# Processing Record 18 of Set 8 | taian
# Processing Record 19 of Set 8 | walvis bay
# Processing Record 20 of Set 8 | katsuura
# Processing Record 21 of Set 8 | walcz
# Processing Record 22 of Set 8 | camana
# Processing Record 23 of Set 8 | barra do garcas
# Processing Record 24 of Set 8 | paamiut
# Processing Record 25 of Set 8 | mecca
# Processing Record 26 of Set 8 | esperance
# Processing Record 27 of Set 8 | jiaozuo
# Processing Record 28 of Set 8 | tromso
# Processing Record 29 of Set 8 | constantine
# Processing Record 30 of Set 8 | kenora
# Processing Record 31 of Set 8 | uruzgan
# Processing Record 32 of Set 8 | saint-pacome
# City not found. Skipping...
# Processing Record 33 of Set 8 | chenzhou
# Processing Record 34 of Set 8 | wukari
# Processing Record 35 of Set 8 | ahtopol
# Processing Record 36 of Set 8 | santa lucia
# Processing Record 37 of Set 8 | esmeraldas
# Processing Record 38 of Set 8 | yerbogachen
# Processing Record 39 of Set 8 | muros
# Processing Record 40 of Set 8 | sao joao da barra
# Processing Record 41 of Set 8 | yenagoa
# Processing Record 42 of Set 8 | asau
# Processing Record 43 of Set 8 | grindavik
# Processing Record 44 of Set 8 | mehamn
# Processing Record 45 of Set 8 | auki
# Processing Record 46 of Set 8 | aleksandrov gay
# Processing Record 47 of Set 8 | srednekolymsk
# Processing Record 48 of Set 8 | bud
# Processing Record 49 of Set 8 | carnarvon
# Processing Record 50 of Set 8 | lakselv
# Processing Record 1 of Set 9 | sao luiz gonzaga
# Processing Record 2 of Set 9 | la ronge
# Processing Record 3 of Set 9 | manturovo
# Processing Record 4 of Set 9 | lasa
# Processing Record 5 of Set 9 | barra patuca
# Processing Record 6 of Set 9 | isangel
# Processing Record 7 of Set 9 | belmonte
# Processing Record 8 of Set 9 | ruteng
# Processing Record 9 of Set 9 | killybegs
# Processing Record 10 of Set 9 | kochi
# Processing Record 11 of Set 9 | bubaque
# Processing Record 12 of Set 9 | pangody
# Processing Record 13 of Set 9 | nizhniy odes
# Processing Record 14 of Set 9 | marshfield
# Processing Record 15 of Set 9 | faanui
# Processing Record 16 of Set 9 | omboue
# Processing Record 17 of Set 9 | karamea
# City not found. Skipping...
# Processing Record 18 of Set 9 | san isidro
# Processing Record 19 of Set 9 | the valley
# Processing Record 20 of Set 9 | huarmey
# Processing Record 21 of Set 9 | hami
# Processing Record 22 of Set 9 | pochutla
# Processing Record 23 of Set 9 | cayenne
# Processing Record 24 of Set 9 | gunnedah
# Processing Record 25 of Set 9 | estrela
# Processing Record 26 of Set 9 | port blair
# Processing Record 27 of Set 9 | padang
# Processing Record 28 of Set 9 | tual
# Processing Record 29 of Set 9 | port lincoln
# Processing Record 30 of Set 9 | pisco
# Processing Record 31 of Set 9 | aktau
# Processing Record 32 of Set 9 | puerto escondido
# Processing Record 33 of Set 9 | sao bernardo
# Processing Record 34 of Set 9 | zhaoyuan
# Processing Record 35 of Set 9 | komsomolets
# Processing Record 36 of Set 9 | la belgica
# Processing Record 37 of Set 9 | balikpapan
# Processing Record 38 of Set 9 | ginir
# Processing Record 39 of Set 9 | zunyi
# Processing Record 40 of Set 9 | peterhead
# Processing Record 41 of Set 9 | karauzyak
# City not found. Skipping...
# Processing Record 42 of Set 9 | dukat
# Processing Record 43 of Set 9 | sahuaripa
# Processing Record 44 of Set 9 | rawson
# Processing Record 45 of Set 9 | metro
# Processing Record 46 of Set 9 | taft
# Processing Record 47 of Set 9 | jawhar
# Processing Record 48 of Set 9 | huntsville
# Processing Record 49 of Set 9 | grantham
# Processing Record 50 of Set 9 | namibe
# Processing Record 1 of Set 10 | igarka
# Processing Record 2 of Set 10 | gonzalez
# Processing Record 3 of Set 10 | cape coast
# Processing Record 4 of Set 10 | spearfish
# Processing Record 5 of Set 10 | cordoba
# Processing Record 6 of Set 10 | pilos
# City not found. Skipping...
# Processing Record 7 of Set 10 | leopold
# Processing Record 8 of Set 10 | sakakah
# Processing Record 9 of Set 10 | ha tinh
# Processing Record 10 of Set 10 | kemijarvi
# Processing Record 11 of Set 10 | tessalit
# Processing Record 12 of Set 10 | lodwar
# Processing Record 13 of Set 10 | nishihara
# Processing Record 14 of Set 10 | harper
# Processing Record 15 of Set 10 | catamarca
# Processing Record 16 of Set 10 | pueblo bello
# Processing Record 17 of Set 10 | najran
# Processing Record 18 of Set 10 | tondano
# Processing Record 19 of Set 10 | cockburn town
# Processing Record 20 of Set 10 | kingsville
# Processing Record 21 of Set 10 | kimbe
# Processing Record 22 of Set 10 | lala
# Processing Record 23 of Set 10 | goure
# Processing Record 24 of Set 10 | barrancabermeja
# Processing Record 25 of Set 10 | cururupu
# Processing Record 26 of Set 10 | salta
# Processing Record 27 of Set 10 | sibut
# Processing Record 28 of Set 10 | lokomotivnyy
# Processing Record 29 of Set 10 | sao paulo de olivenca
# Processing Record 30 of Set 10 | skelleftea
# Processing Record 31 of Set 10 | dunedin
# Processing Record 32 of Set 10 | candido mendes
# Processing Record 33 of Set 10 | gigmoto
# Processing Record 34 of Set 10 | aflu
# City not found. Skipping...
# Processing Record 35 of Set 10 | tarakan
# Processing Record 36 of Set 10 | tilichiki
# Processing Record 37 of Set 10 | sibolga
# Processing Record 38 of Set 10 | aranos
# Processing Record 39 of Set 10 | san francisco
# Processing Record 40 of Set 10 | samalaeulu
# City not found. Skipping...
# Processing Record 41 of Set 10 | mareeba
# Processing Record 42 of Set 10 | kamenskoye
# City not found. Skipping...
# Processing Record 43 of Set 10 | kabinda
# Processing Record 44 of Set 10 | kandrian
# Processing Record 45 of Set 10 | santa isabel do rio negro
# Processing Record 46 of Set 10 | tupik
# Processing Record 47 of Set 10 | kalengwa
# Processing Record 48 of Set 10 | victor harbor
# Processing Record 49 of Set 10 | kenai
# Processing Record 50 of Set 10 | san cristobal
# Processing Record 1 of Set 11 | vanimo
# Processing Record 2 of Set 11 | vuktyl
# Processing Record 3 of Set 11 | cauquenes
# Processing Record 4 of Set 11 | rungata
# City not found. Skipping...
# Processing Record 5 of Set 11 | annau
# Processing Record 6 of Set 11 | matam
# Processing Record 7 of Set 11 | evensk
# Processing Record 8 of Set 11 | riyadh
# Processing Record 9 of Set 11 | la trinidad
# Processing Record 10 of Set 11 | matay
# Processing Record 11 of Set 11 | bafq
# Processing Record 12 of Set 11 | houma
# Processing Record 13 of Set 11 | byron bay
# Processing Record 14 of Set 11 | piacabucu
# Processing Record 15 of Set 11 | ereymentau
# Processing Record 16 of Set 11 | zhifang
# Processing Record 17 of Set 11 | eydhafushi
# Processing Record 18 of Set 11 | zolotinka
# City not found. Skipping...
# Processing Record 19 of Set 11 | mwinilunga
# Processing Record 20 of Set 11 | bonavista
# Processing Record 21 of Set 11 | kutum
# Processing Record 22 of Set 11 | ust-nera
# Processing Record 23 of Set 11 | aripuana
# Processing Record 24 of Set 11 | kisangani
# Processing Record 25 of Set 11 | tabas
# Processing Record 26 of Set 11 | sinnamary
# Processing Record 27 of Set 11 | semnan
# Processing Record 28 of Set 11 | gornopravdinsk
# Processing Record 29 of Set 11 | winneba
# Processing Record 30 of Set 11 | sao jose da coroa grande
# Processing Record 31 of Set 11 | fairbanks
# Processing Record 32 of Set 11 | simbahan
# Processing Record 33 of Set 11 | marsh harbour
# Processing Record 34 of Set 11 | bolshegrivskoye
# City not found. Skipping...
# Processing Record 35 of Set 11 | pavlivka
# Processing Record 36 of Set 11 | paysandu
# Processing Record 37 of Set 11 | caravelas
# Processing Record 38 of Set 11 | lavrentiya
# Processing Record 39 of Set 11 | alotau
# City not found. Skipping...
# Processing Record 40 of Set 11 | abu samrah
# Processing Record 41 of Set 11 | jorpeland
# Processing Record 42 of Set 11 | richards bay
# Processing Record 43 of Set 11 | agropoli
# Processing Record 44 of Set 11 | rio gallegos
# Processing Record 45 of Set 11 | saint-francois
# Processing Record 46 of Set 11 | quebec
# Processing Record 47 of Set 11 | cap malheureux
# Processing Record 48 of Set 11 | san carlos de bariloche
# Processing Record 49 of Set 11 | okhtyrka
# Processing Record 50 of Set 11 | mrirt
# City not found. Skipping...
# Processing Record 1 of Set 12 | toamasina
# Processing Record 2 of Set 12 | los llanos de aridane
# Processing Record 3 of Set 12 | camocim
# Processing Record 4 of Set 12 | jiuquan
# Processing Record 5 of Set 12 | puerto boyaca
# Processing Record 6 of Set 12 | karaul
# City not found. Skipping...
# Processing Record 7 of Set 12 | dryden
# Processing Record 8 of Set 12 | gangotri
# City not found. Skipping...
# Processing Record 9 of Set 12 | baudh
# Processing Record 10 of Set 12 | belyy yar
# Processing Record 11 of Set 12 | petropolis
# Processing Record 12 of Set 12 | canyon lake
# Processing Record 13 of Set 12 | zambezi
# Processing Record 14 of Set 12 | inhambane
# Processing Record 15 of Set 12 | elliot
# Processing Record 16 of Set 12 | loncoche
# Processing Record 17 of Set 12 | marsa matruh
# Processing Record 18 of Set 12 | vestmannaeyjar
# Processing Record 19 of Set 12 | dingle
# Processing Record 20 of Set 12 | putina
# Processing Record 21 of Set 12 | dargaville
# Processing Record 22 of Set 12 | north bend
# Processing Record 23 of Set 12 | lorain
# Processing Record 24 of Set 12 | marogong
# Processing Record 25 of Set 12 | jiayuguan
# Processing Record 26 of Set 12 | arlit
# Processing Record 27 of Set 12 | monte alegre
# Processing Record 28 of Set 12 | mirabad
# Processing Record 29 of Set 12 | camacha
# Processing Record 30 of Set 12 | tamandare
# Processing Record 31 of Set 12 | santa cruz
# Processing Record 32 of Set 12 | alexandria
# Processing Record 33 of Set 12 | te anau
# Processing Record 34 of Set 12 | pokhara
# Processing Record 35 of Set 12 | fort nelson
# Processing Record 36 of Set 12 | korla
# Processing Record 37 of Set 12 | porto-vecchio
# Processing Record 38 of Set 12 | san roque
# Processing Record 39 of Set 12 | nchelenge
# Processing Record 40 of Set 12 | kortkeros
# Processing Record 41 of Set 12 | vanavara
# Processing Record 42 of Set 12 | dunmore town
# Processing Record 43 of Set 12 | charlestown
# Processing Record 44 of Set 12 | ximei
# Processing Record 45 of Set 12 | agsu
# City not found. Skipping...
# Processing Record 46 of Set 12 | azimur
# City not found. Skipping...
# Processing Record 47 of Set 12 | george
# Processing Record 48 of Set 12 | shingu
# Processing Record 49 of Set 12 | jiexiu
# Processing Record 50 of Set 12 | kuldiga
# Processing Record 1 of Set 13 | payson
# Processing Record 2 of Set 13 | mana
# Processing Record 3 of Set 13 | yumen
# Processing Record 4 of Set 13 | mata
# Processing Record 5 of Set 13 | locri
# Processing Record 6 of Set 13 | marawi
# Processing Record 7 of Set 13 | qostanay
# Processing Record 8 of Set 13 | natal
# Processing Record 9 of Set 13 | saint-georges
# Processing Record 10 of Set 13 | kawalu
# Processing Record 11 of Set 13 | kysyl-syr
# Processing Record 12 of Set 13 | ngukurr
# City not found. Skipping...
# Processing Record 13 of Set 13 | sri aman
# Processing Record 14 of Set 13 | terrace bay
# Processing Record 15 of Set 13 | prince rupert
# Processing Record 16 of Set 13 | salinopolis
# Processing Record 17 of Set 13 | egvekinot
# Processing Record 18 of Set 13 | aswan
# Processing Record 19 of Set 13 | anar darreh
# City not found. Skipping...
# Processing Record 20 of Set 13 | bur gabo
# City not found. Skipping...
# Processing Record 21 of Set 13 | gat
# Processing Record 22 of Set 13 | urzhum
# Processing Record 23 of Set 13 | lahij
# Processing Record 24 of Set 13 | mackay
# Processing Record 25 of Set 13 | ketchikan
# Processing Record 26 of Set 13 | amboasary
# Processing Record 27 of Set 13 | novaya ladoga
# Processing Record 28 of Set 13 | sterling
# Processing Record 29 of Set 13 | roma
# Processing Record 30 of Set 13 | panzhihua
# Processing Record 31 of Set 13 | joshimath
# Processing Record 32 of Set 13 | khandyga
# Processing Record 33 of Set 13 | coripata
# Processing Record 34 of Set 13 | skjervoy
# Processing Record 35 of Set 13 | niquero
# Processing Record 36 of Set 13 | oyama
# Processing Record 37 of Set 13 | oksfjord
# Processing Record 38 of Set 13 | coacoyul
# Processing Record 39 of Set 13 | mnogovershinnyy
# Processing Record 40 of Set 13 | arzgir
# Processing Record 41 of Set 13 | baruun-urt
# Processing Record 42 of Set 13 | fare
# Processing Record 43 of Set 13 | parabel
# Processing Record 44 of Set 13 | shahrud
# Processing Record 45 of Set 13 | talnakh
# Processing Record 46 of Set 13 | kamenka
# Processing Record 47 of Set 13 | moa
# Processing Record 48 of Set 13 | bure
# Processing Record 49 of Set 13 | obanazawa
# Processing Record 50 of Set 13 | odessa
# Processing Record 1 of Set 14 | niteroi
# Processing Record 2 of Set 14 | tommot
# Processing Record 3 of Set 14 | maumere
# Processing Record 4 of Set 14 | tharad
# Processing Record 5 of Set 14 | carora
# Processing Record 6 of Set 14 | elbistan
# Processing Record 7 of Set 14 | leh
# Processing Record 8 of Set 14 | cabinda
# Processing Record 9 of Set 14 | northam
# Processing Record 10 of Set 14 | astoria
# Processing Record 11 of Set 14 | shepsi
# Processing Record 12 of Set 14 | veraval
# Processing Record 13 of Set 14 | atambua
# Processing Record 14 of Set 14 | tomakomai
# Processing Record 15 of Set 14 | sarahan
# Processing Record 16 of Set 14 | kungurtug
# Processing Record 17 of Set 14 | cam ranh
# Processing Record 18 of Set 14 | kieta
# Processing Record 19 of Set 14 | vila franca do campo
# Processing Record 20 of Set 14 | thunder bay
# Processing Record 21 of Set 14 | palizada
# Processing Record 22 of Set 14 | iquique
# Processing Record 23 of Set 14 | kailua
# Processing Record 24 of Set 14 | lolua
# City not found. Skipping...
# Processing Record 25 of Set 14 | haines junction
# Processing Record 26 of Set 14 | santa maria
# Processing Record 27 of Set 14 | sorvag
# City not found. Skipping...
# Processing Record 28 of Set 14 | sarh
# Processing Record 29 of Set 14 | palauig
# Processing Record 30 of Set 14 | yakeshi
# Processing Record 31 of Set 14 | poltavka
# Processing Record 32 of Set 14 | disna
# Processing Record 33 of Set 14 | kumluca
# Processing Record 34 of Set 14 | labelle
# Processing Record 35 of Set 14 | pengcheng
# Processing Record 36 of Set 14 | edson
# Processing Record 37 of Set 14 | acapulco
# Processing Record 38 of Set 14 | pingliang
# Processing Record 39 of Set 14 | altay
# Processing Record 40 of Set 14 | baykit
# Processing Record 41 of Set 14 | mercedes
# Processing Record 42 of Set 14 | daru
# Processing Record 43 of Set 14 | barinas
# Processing Record 44 of Set 14 | great falls
# Processing Record 45 of Set 14 | jackson
# Processing Record 46 of Set 14 | maxixe
# Processing Record 47 of Set 14 | svetlogorsk
# Processing Record 48 of Set 14 | nikolayevsk-na-amure
# Processing Record 49 of Set 14 | ugoofaaru
# Processing Record 50 of Set 14 | kachiry
# Processing Record 1 of Set 15 | port macquarie
# Processing Record 2 of Set 15 | oneonta
# Processing Record 3 of Set 15 | agua dulce
# Processing Record 4 of Set 15 | puerto leguizamo
# Processing Record 5 of Set 15 | taksimo
# Processing Record 6 of Set 15 | langfang
# Processing Record 7 of Set 15 | anchorage
# Processing Record 8 of Set 15 | lucapa
# Processing Record 9 of Set 15 | la asuncion
# Processing Record 10 of Set 15 | umm durman
# City not found. Skipping...
# Processing Record 11 of Set 15 | rocha
# Processing Record 12 of Set 15 | dong xoai
# Processing Record 13 of Set 15 | port-cartier
# Processing Record 14 of Set 15 | chiusi
# Processing Record 15 of Set 15 | karratha
# Processing Record 16 of Set 15 | verkhnyaya inta
# Processing Record 17 of Set 15 | kemi
# Processing Record 18 of Set 15 | rijkevorsel
# Processing Record 19 of Set 15 | altagracia de orituco
# Processing Record 20 of Set 15 | raymond
# Processing Record 21 of Set 15 | mapastepec
# Processing Record 22 of Set 15 | tucuma
# Processing Record 23 of Set 15 | kommunisticheskiy
# Processing Record 24 of Set 15 | jiddah
# City not found. Skipping...
# Processing Record 25 of Set 15 | poum
# Processing Record 26 of Set 15 | amapa
# Processing Record 27 of Set 15 | umm lajj
# Processing Record 28 of Set 15 | russell
# Processing Record 29 of Set 15 | karacabey
# Processing Record 30 of Set 15 | labuan
# Processing Record 31 of Set 15 | champerico
# Processing Record 32 of Set 15 | ust-maya
# Processing Record 33 of Set 15 | peniche
# Processing Record 34 of Set 15 | sarandi
# Processing Record 35 of Set 15 | baltiysk
# Processing Record 36 of Set 15 | satipo
# Processing Record 37 of Set 15 | preobrazheniye
# Processing Record 38 of Set 15 | buala
# Processing Record 39 of Set 15 | ventspils
# Processing Record 40 of Set 15 | san policarpo
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the city count to confirm sufficient count.
len(city_data)
# Out:
# 682

# %%
# Data to DataFrame
city_data_df = pd.DataFrame(city_data)
city_data_df.head()
# Out:
#          City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0     Mataura -46.1927  168.8643     50.00        79         100        5.01
# 1      Torbay  47.6666  -52.7314     61.57        36          20       10.36
# 2  Codrington -38.2667  141.9667     40.30        67           5        8.23
# 3       Kapaa  22.0752 -159.3190     79.00        73           1        8.05
# 4      Dikson  73.5069   80.5464     30.34        93         100        6.71
#
#   Country Current Description
# 0      NZ          light rain
# 1      CA          few clouds
# 2      AU           clear sky
# 3      US           clear sky
# 4      RU     overcast clouds

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head()
# Out:
#          City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Mataura      NZ -46.1927  168.8643     50.00        79         100
# 1      Torbay      CA  47.6666  -52.7314     61.57        36          20
# 2  Codrington      AU -38.2667  141.9667     40.30        67           5
# 3       Kapaa      US  22.0752 -159.3190     79.00        73           1
# 4      Dikson      RU  73.5069   80.5464     30.34        93         100
#
#    Wind Speed Current Description
# 0        5.01          light rain
# 1       10.36          few clouds
# 2        8.23           clear sky
# 3        8.05           clear sky
# 4        6.71     overcast clouds

# %%
# Format the columns.
city_data_df["Lat"] = city_data_df["Lat"].map("{:.2f}".format)
city_data_df["Lng"] = city_data_df["Lng"].map("{:.2f}".format)
city_data_df.head()
# Out:
#          City Country     Lat      Lng  Max Temp  Humidity  Cloudiness  \
# 0     Mataura      NZ  -46.19   168.86     50.00        79         100
# 1      Torbay      CA   47.67   -52.73     61.57        36          20
# 2  Codrington      AU  -38.27   141.97     40.30        67           5
# 3       Kapaa      US   22.08  -159.32     79.00        73           1
# 4      Dikson      RU   73.51    80.55     30.34        93         100
#
#    Wind Speed Current Description
# 0        5.01          light rain
# 1       10.36          few clouds
# 2        8.23           clear sky
# 3        8.05           clear sky
# 4        6.71     overcast clouds

# %%
# Save data to csv.file
city_data_df.to_csv("WeatherPy_Database.csv",index_label="city_id")
